# %% [markdown]
# # Programming Project - Unit 1,2
# *by Igor A. Brandão*
#
# **Goals**
# - Access data from ckan.imd.ufrn.br
# - Generate a Histogram/bar figure reporting the number of "municipal schools" and "health units"
# - Geocoder figure about those units
# - A heatmap figure considering the number of employees in each unit

# %% [markdown]
# ## Imports
#
# Import the necessary libraries to handle geocoding and maps

# %%
### Library necessary to run this IPython Notebook
# !pip install geocoder
# !pip install folium
# !pip install tqdm
# Out:
# Requirement already satisfied: geocoder in /home/igorbrandao/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: six in /home/igorbrandao/anaconda3/lib/python3.6/site-packages (from geocoder)
# Requirement already satisfied: ratelim in /home/igorbrandao/anaconda3/lib/python3.6/site-packages (from geocoder)
# Requirement already satisfied: requests in /home/igorbrandao/anaconda3/lib/python3.6/site-packages (from geocoder)
# Requirement already satisfied: click in /home/igorbrandao/anaconda3/lib/python3.6/site-packages (from geocoder)
# Requirement already satisfied: decorator in /home/igorbrandao/anaconda3/lib/python3.6/site-packages (from ratelim->geocoder)
# Requirement already satisfied: folium in /home/igorbrandao/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: six in /home/igorbrandao/anaconda3/lib/python3.6/site-packages (from folium)
# Requirement already satisfied: Jinja2 in /home/igorbrandao/anaconda3/lib/python3.6/site-packages (from folium)
# Requirement already satisfied: branca in /home/igorbrandao/anaconda3/lib/python3.6/site-packages (from folium)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/igorbrandao/anaconda3/lib/python3.6/site-packages (from Jinja2->folium)
# Requirement already satisfied: tqdm in /home/igorbrandao/anaconda3/lib/python3.6/site-packages

# %%
# Import tthe necessary libraries

import pandas as pd
import geocoder as gc
import numpy as np
import folium
from folium.plugins import HeatMap
from tqdm import tqdm
from bokeh.charts import Bar, output_notebook, show
from bokeh.layouts import row
from bokeh.models import HoverTool
from bokeh.charts.attributes import cat, color
from bokeh.charts.operations import blend

# Receive data from ckan
sab = "http://ckan.imd.ufrn.br/dataset/121bed36-e220-410c-8e87-eabfe2319bd7/resource/83c21ba5-c3a9-4876-8e65-3168ba392d1a/download/servicos-de-atencao-basica.csv"
sae = "http://ckan.imd.ufrn.br/dataset/121bed36-e220-410c-8e87-eabfe2319bd7/resource/52935484-0a23-4e13-b920-277448c66c8f/download/servicos-de-atencao-especializada.csv"

# Split the data using ';'
data1 = pd.read_csv(sae, sep=";")
data2 = pd.read_csv(sab, sep=";")

# Print the data
print(data1.columns.values.tolist())
print(data2.columns.values.tolist())
# Out:
# ['Distrito Sanitário', 'Unidade', 'Serviços Oferecidos', 'Tipo de Unidade']
# ['Distrito Sanitário', 'Unidade', 'Serviços Oferecidos', 'Tipo de Unidade']

# %% [markdown]
# ## Data printing

# %%
data1.head()
# Out:
#   Distrito Sanitário           Unidade         Serviços Oferecidos  \
# 0              Leste  CAPS AD II LESTE      Consulta Clinico Geral
# 1              Leste  CAPS AD II LESTE         Consulta Enfermagem
# 2              Leste  CAPS AD II LESTE           Consulta Nutrição
# 3              Leste  CAPS AD II LESTE      Consulta de Psicologia
# 4              Leste  CAPS AD II LESTE  Consulta Assistente Social
#
#                   Tipo de Unidade
# 0  CENTRO DE ATENÇÃO PSICOSSOCIAL
# 1  CENTRO DE ATENÇÃO PSICOSSOCIAL
# 2  CENTRO DE ATENÇÃO PSICOSSOCIAL
# 3  CENTRO DE ATENÇÃO PSICOSSOCIAL
# 4  CENTRO DE ATENÇÃO PSICOSSOCIAL

# %%
data2.tail()
# Out:
#     Distrito Sanitário       Unidade    Serviços Oferecidos Tipo de Unidade
# 815                Sul  USF PLANALTO  Consulta Odontologica             NaN
# 816                Sul  USF PLANALTO      Consulta Nutrição             NaN
# 817                Sul  USF PLANALTO              Pré-Natal             NaN
# 818                Sul  USF PLANALTO            CD Coletivo             NaN
# 819                Sul  USF PLANALTO              Regulação             NaN

# %% [markdown]
# ## Data appending
#
# Joing the data from different array in only one.
#
# Add an index column and remove the previous one.

# %%
# Append data2 in data1
data1 = data1.append(data2)

# Reset the index
data1 = data1.reset_index()

# Remove the the previous index
data1.drop(data1.columns[0], axis=1, inplace=True)

# Print the new data1
data1
# Out:
#      Distrito Sanitário                                      Unidade  \
# 0                 Leste                             CAPS AD II LESTE
# 1                 Leste                             CAPS AD II LESTE
# 2                 Leste                             CAPS AD II LESTE
# 3                 Leste                             CAPS AD II LESTE
# 4                 Leste                             CAPS AD II LESTE
# 5                 Leste                             CAPS AD II LESTE
# 6                 Leste                             CAPS AD II LESTE
# 7                 Leste                             CAPS AD II LESTE
# 8                 Leste                             CAPS AD II LESTE
# 9                 Leste                             CAPS AD II LESTE
# 10                Leste                             CAPS AD II LESTE
# 11                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 12                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 13                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 14                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 15                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 16                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 17                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 18                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 19                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 20                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 21                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 22                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 23                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 24                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 25                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 26                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 27                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 28                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# 29                Leste  CENTRO DE ESPECIALIDADES INTEGRADAS LESTE I
# ...                 ...                                          ...
# 3453                Sul                              UBS PONTA NEGRA
# 3454                Sul                              UBS PONTA NEGRA
# 3455                Sul                              UBS PONTA NEGRA
# 3456                Sul                              UBS PONTA NEGRA
# 3457                Sul                              UBS PONTA NEGRA
# 3458                Sul                              UBS PONTA NEGRA
# 3459                Sul                              UBS PONTA NEGRA
# 3460                Sul                              UBS PONTA NEGRA
# 3461                Sul                              UBS PONTA NEGRA
# 3462                Sul                              UBS PONTA NEGRA
# 3463                Sul                              UBS PONTA NEGRA
# 3464                Sul                              UBS PONTA NEGRA
# 3465                Sul                              UBS PONTA NEGRA
# 3466                Sul                              UBS PONTA NEGRA
# 3467                Sul                              UBS PONTA NEGRA
# 3468                Sul                              UBS PONTA NEGRA
# 3469                Sul                                 USF PLANALTO
# 3470                Sul                                 USF PLANALTO
# 3471                Sul                                 USF PLANALTO
# 3472                Sul                                 USF PLANALTO
# 3473                Sul                                 USF PLANALTO
# 3474                Sul                                 USF PLANALTO
# 3475                Sul                                 USF PLANALTO
# 3476                Sul                                 USF PLANALTO
# 3477                Sul                                 USF PLANALTO
# 3478                Sul                                 USF PLANALTO
# 3479                Sul                                 USF PLANALTO
# 3480                Sul                                 USF PLANALTO
# 3481                Sul                                 USF PLANALTO
# 3482                Sul                                 USF PLANALTO
#
#                                     Serviços Oferecidos  \
# 0                                Consulta Clinico Geral
# 1                                   Consulta Enfermagem
# 2                                     Consulta Nutrição
# 3                                Consulta de Psicologia
# 4                            Consulta Assistente Social
# 5                        Vivências lúdicas integrativas
# 6                                      Atividade Física
# 7                                           Psiquiatria
# 8                                             Geriatria
# 9                          Internação em clínica médica
# 10                     Atend. Urgência / Atenção Espec.
# 11                                         Teste Rápido
# 12                               Consulta Clinico Geral
# 13                                 Consulta Ginecologia
# 14                                  Consulta Enfermagem
# 15                           Consulta Assistente Social
# 16                                          Fitoterapia
# 17                   Realização de exames laboratoriais
# 18                                   Pequenas Cirurgias
# 19                                          Psiquiatria
# 20                       Ultra - Membros / articulações
# 21                                          Cardiologia
# 22                                         Dermatologia
# 23                                      Endrocrinologia
# 24                                         Reumatologia
# 25                                         Mastologista
# 26                                         Neurologista
# 27                                       Oftalmologista
# 28                                          Ortopedista
# 29                                             Otorrino
# ...                                                 ...
# 3453                                        Nebulização
# 3454                                 Retirada de Pontos
# 3455  Exame Citopatológico do Colo de Útero (Prevent...
# 3456                              Emissão do Cartão SUS
# 3457                             Consulta Clinico Geral
# 3458                                 Consulta Pediatria
# 3459                               Consulta Ginecologia
# 3460                              Consulta Odontologica
# 3461                                  Consulta Nutrição
# 3462                             Consulta de Psicologia
# 3463                         Consulta Assistente Social
# 3464                                          Pré-Natal
# 3465                                        CD Coletivo
# 3466                                          Regulação
# 3467                                      Esterelização
# 3468                                        Laboratório
# 3469                                         Imunização
# 3470                                           Curativo
# 3471                                        Nebulização
# 3472                                 Retirada de Pontos
# 3473  Exame Citopatológico do Colo de Útero (Prevent...
# 3474                                                BCG
# 3475                              Emissão do Cartão SUS
# 3476                  Consulta médico Generalista (ESF)
# 3477                             Consulta Clinico Geral
# 3478                              Consulta Odontologica
# 3479                                  Consulta Nutrição
# 3480                                          Pré-Natal
# 3481                                        CD Coletivo
# 3482                                          Regulação
#
#                      Tipo de Unidade
# 0     CENTRO DE ATENÇÃO PSICOSSOCIAL
# 1     CENTRO DE ATENÇÃO PSICOSSOCIAL
# 2     CENTRO DE ATENÇÃO PSICOSSOCIAL
# 3     CENTRO DE ATENÇÃO PSICOSSOCIAL
# 4     CENTRO DE ATENÇÃO PSICOSSOCIAL
# 5     CENTRO DE ATENÇÃO PSICOSSOCIAL
# 6     CENTRO DE ATENÇÃO PSICOSSOCIAL
# 7     CENTRO DE ATENÇÃO PSICOSSOCIAL
# 8     CENTRO DE ATENÇÃO PSICOSSOCIAL
# 9     CENTRO DE ATENÇÃO PSICOSSOCIAL
# 10    CENTRO DE ATENÇÃO PSICOSSOCIAL
# 11                       POLICLINICA
# 12                       POLICLINICA
# 13                       POLICLINICA
# 14                       POLICLINICA
# 15                       POLICLINICA
# 16                       POLICLINICA
# 17                       POLICLINICA
# 18                       POLICLINICA
# 19                       POLICLINICA
# 20                       POLICLINICA
# 21                       POLICLINICA
# 22                       POLICLINICA
# 23                       POLICLINICA
# 24                       POLICLINICA
# 25                       POLICLINICA
# 26                       POLICLINICA
# 27                       POLICLINICA
# 28                       POLICLINICA
# 29                       POLICLINICA
# ...                              ...
# 3453                             NaN
# 3454                             NaN
# 3455                             NaN
# 3456                             NaN
# 3457                             NaN
# 3458                             NaN
# 3459                             NaN
# 3460                             NaN
# 3461                             NaN
# 3462                             NaN
# 3463                             NaN
# 3464                             NaN
# 3465                             NaN
# 3466                             NaN
# 3467                             NaN
# 3468                             NaN
# 3469                             NaN
# 3470                             NaN
# 3471                             NaN
# 3472                             NaN
# 3473                             NaN
# 3474                             NaN
# 3475                             NaN
# 3476                             NaN
# 3477                             NaN
# 3478                             NaN
# 3479                             NaN
# 3480                             NaN
# 3481                             NaN
# 3482                             NaN
#
# [3483 rows x 4 columns]

# %% [markdown]
# # Health units handler

# %%
# Retrieve the uniques health units
unique_health_units = data1["Distrito Sanitário"].unique().tolist()

# Count the health units
units_count_dict = {}
for atual in unique_health_units:
    units_count_dict[atual] = data1[data1 == atual]["Distrito Sanitário"].count() 

# Read the data from dictionary
health_units = pd.DataFrame.from_dict(units_count_dict, orient='index')

# Get the data with index 'Region'
health_units.index.name = "Region"

# Append the count column
health_units.columns = ["Count"]

# Reset the data index
health_units = health_units.reset_index()

# Print the dataSet
print(health_units)
# Out:
#      Region  Count
# 0     Leste    687
# 1   Norte I    526
# 2  Norte II   1051
# 3     Oeste    710
# 4       Sul    509

# %% [markdown]
# ## Health units chart
#
# Histogram/bar figure reporting the number of "health units"

# %%
hover = HoverTool(tooltips=[('Quantidade', '$y{int}')])

bar = Bar(unidades_count, values="Count", label="Region", color="Region", title= "Unidades de saúde por região",
         ylabel ="Quantidade de unidades")
bar.add_tools(hover)

output_notebook()

show(bar)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e2cc639b-a5d2-49fb-8c19-3de40667058e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2c6dce1b-a5e7-437f-aa5a-1c8e4344b49a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("2c6dce1b-a5e7-437f-aa5a-1c8e4344b49a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2c6dce1b-a5e7-437f-aa5a-1c8e4344b49a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2c6dce1b-a5e7-437f-aa5a-1c8e4344b49a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"eb17e0c2-b2ce-4fec-85a6-0365e28a1f4f":{"roots":{"references":[{"attributes":{"plot":{"id":"bcc14cc4-12e3-4748-95de-91d7a38e9890","subtype":"Chart","type":"Plot"}},"id":"7d4f5d23-be18-4c92-8c37-c66832fee607","type":"HelpTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4520ccdc-3c3d-4a36-a3df-084b624163dc","type":"Rect"},{"attributes":{},"id":"e9a66952-a256-4821-99a2-0ab2e7f91c1b","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"b6115daf-1bbf-4cbd-b317-dd2959778784","type":"ColumnDataSource"},"glyph":{"id":"4520ccdc-3c3d-4a36-a3df-084b624163dc","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2a71a7bc-3ebd-409c-8136-1be0280df666","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["Leste","Norte I","Norte II","Oeste","Sul"]},"id":"762adc81-28ea-4193-8fc8-433c3ec35526","type":"FactorRange"},{"attributes":{},"id":"5b66637b-9d3e-4dda-8f80-00ad9bac3f0f","type":"ToolEvents"},{"attributes":{"data_source":{"id":"38484a7a-9d24-463f-a6e6-f9eb087ae3f2","type":"ColumnDataSource"},"glyph":{"id":"b9ee5ef8-a802-49dd-be9b-d43d140493e2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"78d9c796-27bc-4901-9a01-af507d1dc764","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Region":["Norte I"],"chart_index":[{"Region":"Norte I"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[139.0],"label":[{"Region":"Norte I"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["Norte I"],"y":[69.5]}},"id":"4cb76ee2-8326-4c14-af2e-f8bd54b12094","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"74318999-2125-4878-b470-38ed21b17f95","type":"ColumnDataSource"},"glyph":{"id":"c134a717-4d6f-4af8-b34d-1c3b25655ad5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"72f6e49e-4431-4cc0-a131-fceadd244513","type":"GlyphRenderer"},{"attributes":{"label":{"value":"Leste"},"renderers":[{"id":"2a71a7bc-3ebd-409c-8136-1be0280df666","type":"GlyphRenderer"}]},"id":"845145f3-dd39-4609-83bd-2859242e5d1a","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c37f2c0f-e3d9-4edb-97fc-3ade70a1d317","type":"PanTool"},{"id":"a9d26338-f9bc-47db-81b9-4d5f6e5f8352","type":"WheelZoomTool"},{"id":"3e268c08-734f-49af-bcaf-d3ae3e79aedb","type":"BoxZoomTool"},{"id":"5ef646b3-72c0-4e93-a637-5d2244440443","type":"SaveTool"},{"id":"7eec6933-4587-4b87-beb3-b0723ffbe3a0","type":"ResetTool"},{"id":"7d4f5d23-be18-4c92-8c37-c66832fee607","type":"HelpTool"},{"id":"557031aa-15c2-4b5f-a00c-5fd8d8bd0b2b","type":"HoverTool"}]},"id":"8ff8bf94-749f-43a5-8866-2cc71991ff47","type":"Toolbar"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"02840c1f-0952-4089-b2a9-0f954f358a74","type":"Rect"},{"attributes":{"below":[{"id":"f1840d3b-04df-43cb-8a2d-3c6f657e1620","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"6ed1d46f-2d3a-48f9-8b92-8e75780e7062","type":"LinearAxis"}],"renderers":[{"id":"7e6b9fdb-d400-4ffc-b9ee-46d14640c26e","type":"BoxAnnotation"},{"id":"2a71a7bc-3ebd-409c-8136-1be0280df666","type":"GlyphRenderer"},{"id":"fbea7f1b-83b4-4ed5-9d0f-191d8dd6963c","type":"GlyphRenderer"},{"id":"78d9c796-27bc-4901-9a01-af507d1dc764","type":"GlyphRenderer"},{"id":"d1f45909-60c8-4097-b3f5-354756c2629e","type":"GlyphRenderer"},{"id":"72f6e49e-4431-4cc0-a131-fceadd244513","type":"GlyphRenderer"},{"id":"a1ecd19b-e642-4621-878c-effb913deec5","type": ...

# %% [markdown]
# # Schools handler

# %%
# Receive data from ckan
url_schools = "http://ckan.imd.ufrn.br/dataset/9b362c15-832b-4aa9-9dfe-a5e015b3ce54/resource/8ad5f0d9-3ffc-41c4-84c4-f7e0cf4f2b5b/download/total-de-estabelecimentos-por-modalidade-de-ensino.csv"

# Split the data using ';'
data2 = pd.read_csv(url_schools, sep=";")

# Print the dataSet head
data2.head()
# Out:
#   Regiões Administrativas  Creches (CMEIS)  \
# 0                     SUL               11
# 1                   LESTE                9
# 2                   OESTE               21
# 3                   NORTE               23
#
#    Pré-escolas  de Ens. Infantil (CMEIS)  Pré-escolas de Ens. Infantil  \
# 0                                     11                             2
# 1                                      6                             5
# 2                                     20                             4
# 3                                     25                             1
#
#    Anos Iniciais do Ens. Fundamental  Anos Finais do Ens. Fundamental  EJA
# 0                                  7                                5    3
# 1                                  6                                3    1
# 2                                 22                                8   11
# 3                                 27                               15   10

# %% [markdown]
# ## Schools chart
#
# Histogram/bar figure reporting the number of "municipal schools"

# %%
# Chart layers
BLEND = blend('Creches (CMEIS)', "Pré-escolas de Ens. Infantil (CMEIS)", "Pré-escolas de Ens. Infantil",
              "Anos Iniciais do Ens. Fundamental", "Anos Finais do Ens. Fundamental", 'EJA',
              name='unidade', labels_name='Unidades')

# Attach the dataSet and layers to the bar chart
bar = Bar(data2, values=BLEND,
          label=cat(columns='Regiões Administrativas', sort=False),
          stack=cat(columns='Unidades', sort=False),
          color="Unidades",
          legend='top_left',
          title="Total de escolas por região",
          ylabel = "Soma das unidades",
          tooltips=[('Tipo', '@Unidades')])

# Print the chart
output_notebook()
show(bar)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="09101405-addb-4b6b-9906-7cbf2e3806e8">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="db7cec99-24fd-4616-b567-4914e85cc1ea"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("db7cec99-24fd-4616-b567-4914e85cc1ea").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("db7cec99-24fd-4616-b567-4914e85cc1ea");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'db7cec99-24fd-4616-b567-4914e85cc1ea' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a0b80139-154d-437f-b058-b37eda68d366":{"roots":{"references":[{"attributes":{"data_source":{"id":"31e962a0-e001-48ca-b13c-8bc58705d4e1","type":"ColumnDataSource"},"glyph":{"id":"05fb44fa-85fd-4b93-b0e7-f6bec29b3c3b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"fa1c9087-09b2-4708-9579-f177d6f1c13b","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"f89550c4-ac54-4f3e-9966-1be8abf92c50","type":"ColumnDataSource"},"glyph":{"id":"69eef9eb-50df-444c-89f0-8b3f472afe04","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2f48884b-85ab-4003-918f-61ba33dc32cb","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7b583251-b0c5-4ba0-a626-05d9166412aa","type":"Rect"},{"attributes":{},"id":"b4a6ce6d-c58b-45cd-b2b4-4c811f903309","type":"BasicTickFormatter"},{"attributes":{"axis_label":"Regi\u00f5es Administrativas","formatter":{"id":"ad59507d-fd81-48f8-a8ba-988fcdc50822","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"dfcc5908-98c5-4e79-b069-daa06074cc46","subtype":"Chart","type":"Plot"},"ticker":{"id":"e2de7a16-9320-4559-add6-d04613bcb6cd","type":"CategoricalTicker"}},"id":"dccacc17-b948-4525-a699-cab18a5411eb","type":"CategoricalAxis"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Regi\u00f5es Administrativas":["OESTE"],"Unidades":["Pr\u00e9-escolas de Ens. Infantil (CMEIS)"],"chart_index":[{"Regi\u00f5es Administrativas":"OESTE","Unidades":"Pr\u00e9-escolas de Ens. Infantil (CMEIS)"}],"color":["#c33ff3"],"fill_alpha":[0.8],"height":[0.0],"label":[{"Regi\u00f5es Administrativas":"OESTE","Unidades":"Pr\u00e9-escolas de Ens. Infantil (CMEIS)"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["OESTE"],"y":[21.0]}},"id":"2f37ee17-0b6a-47a8-b418-81699aa493bf","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"6d6a062b-b48b-4c0b-9c51-7b965c878dcf","type":"BoxAnnotation"},"plot":{"id":"dfcc5908-98c5-4e79-b069-daa06074cc46","subtype":"Chart","type":"Plot"}},"id":"413d3b44-b991-46a2-88c5-40b3ebfe97b4","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"dfcc5908-98c5-4e79-b069-daa06074cc46","subtype":"Chart","type":"Plot"}},"id":"62f2a3d9-9130-480c-a185-d649b42bc52b","type":"PanTool"},{"attributes":{"plot":{"id":"dfcc5908-98c5-4e79-b069-daa06074cc46","subtype":"Chart","type":"Plot"}},"id":"5e881693-08e7-4744-9947-e95918165619","type":"SaveTool"},{"attributes":{"data_source":{"id":"26e251ab-b8fc-4a0a-979e-f281ba0e5c69","type":"ColumnDataSource"},"glyph":{"id":"e059e9f2-352f-4595-a437-a098e9ac0463","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"72f3b849-f8ea-4c75-bb6d-fe9964811465","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Regi\u00f5es Administrativas":["SUL"],"Unidades":["Pr\u00e9-escolas de Ens. Infantil"],"chart_index":[{"Regi\u00f5es Administrativas":"SUL","Unidades":"Pr\u00e9-escolas de Ens. Infantil"}],"color":["#00ad9c"],"fill_alpha":[0.8],"height":[2.0],"label":[{"Regi\u00f5es Administrativas":"SUL","Unidades":"Pr\u00e9-escolas de Ens. Infantil"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["SUL"],"y":[12.0]}},"id":"f89550c4-ac54-4f3e-9966-1be8abf92c50","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"Regi\u00f5es Administrativas":["SUL"],"Unidades":["EJA"],"chart_index":[{"Regi\u00f5es Administrativas":"SUL","Unidades":"EJA"}],"color":["#df5320"],"fill_alpha":[0.8],"h ...

# %% [markdown]
# # Geolocation handler

# %% [markdown]
# ### Geolocation - schools

# %%
# Receive data from ckan
cmeis = "http://ckan.imd.ufrn.br/dataset/9b362c15-832b-4aa9-9dfe-a5e015b3ce54/resource/6d8e8580-bb48-4d75-a55c-4fa04da23919/download/cmeis-por-regioes-administrativas.csv"
schools = "http://ckan.imd.ufrn.br/dataset/9b362c15-832b-4aa9-9dfe-a5e015b3ce54/resource/99e0eef6-e16c-4ed8-bf62-d6bca9626eeb/download/escolas-por-regioes-administrativas.csv"

# Split the data using ';'
data3 = pd.read_csv(cmeis, sep=";")
data4 = pd.read_csv(schools, sep=";")

# Print the dataSet head
print(data3.head())
print(data4.head())
# Out:
#   Região Administrativa    CÓDIGO                       ESTABELECIMENTO  \
# 0                   SUL  24077720            CMEI CLAUDETE COSTA MACIEL
# 1                   SUL  24077739  CMEI HAYDEE MONTEIRO BEZERRA DE MELO
# 2                   SUL  24056936            CMEI KÁTIA FAGUNDES GARCIA
# 3                   SUL  24077267              CMEI MARIA CELONI CAMPOS
# 4                   SUL  24077500       CMEI MOEMA TINOCO DA CUNHA LIMA
#
#                      ENDEREÇO    Nº         BAIRRO       CEP        FONE
# 0       RUA SERRA DOS CARAJAS  3160        PITIMBU  59068200  32328403.0
# 1            RUA JOSÉ SELEDON    70    PONTA NEGRA  59090215  32328413.0
# 2  RUA PROFESSORA ANA DJANIRA  1960     CANDELÁRIA  59064480  87291989.0
# 3            RUA BAIA FORMOSÁ  1517  LAGOA NOVA II  59063060  32329443.0
# 4                   RUA JACUI   217       NEÓPOLIS  59080270  32328376.0
#   Região Administrativa    CÓDIGO                        ESTABELECIMENTO  \
# 0                   SUL  24058890         ESC MUL PROF ANTÔNIO SEVERIANO
# 1                   SUL  24058912  ESC MUL PROF ARNALDO MONTEIRO BEZERRA
# 2                   SUL  24060690      ESC MUL PROF ASCENDINO DE ALMEIDA
# 3                   SUL  24058793       ESC MUL PROF CARLOS BELLO MORENO
# 4                   SUL  24075710      ESC MUL PROF OTTO DE BRITO GUERRA
#
#               ENDEREÇO    Nº    BAIRRO       CEP      FONE
# 0        AV OURO PRETO  2754  NEÓPOLIS  59088690  32324762
# 1            ARACITABA  2993  NEÓPOLIS  59084080  32324763
# 2  RUA JOAQUIM CARDOSO   NaN   PITIMBU  59069010  32324767
# 3        RUA ARAPIRACA    SN  NEÓPOLIS  59086210  32324761
# 4  RUA SERRA DA JUREMA    SN   PITIMBU  59068150  32328373

# %%
# Append data4 in data3
data3 = data3.append(data4)

# Reset the index
data3 = data3.reset_index()

# Remove the the previous index
data3.drop(data3.columns[0], axis=1, inplace=True)

# Print the new data1
data3
# Out:
#     Região Administrativa    CÓDIGO  \
# 0                     SUL  24077720
# 1                     SUL  24077739
# 2                     SUL  24056936
# 3                     SUL  24077267
# 4                     SUL  24077500
# 5                     SUL  24084298
# 6                     SUL  24081221
# 7                     SUL  24064440
# 8                     SUL  24085332
# 9                     SUL  24064785
# 10                    SUL  24077747
# 11                    SUL  24077682
# 12                  LESTE  24077712
# 13                  LESTE  24077496
# 14                  LESTE  24077534
# 15                  LESTE  24077330
# 16                  LESTE  24077887
# 17                  LESTE  24077585
# 18                  LESTE  24077607
# 19                  LESTE  24082937
# 20                  LESTE  24056952
# 21                  LESTE  24077470
# 22                  OESTE  24077925
# 23                  OESTE  24091804
# 24                  OESTE  24077569
# 25                  OESTE  24074470
# 26                  OESTE  24077666
# 27                  OESTE  24077690
# 28                  OESTE  24077410
# 29                  OESTE  24059498
# ..                    ...       ...
# 115                 NORTE  24078700
# 116                 NORTE  24284327
# 117                 NORTE  24060682
# 118                 NORTE  24060313
# 119                 NORTE  24082635
# 120                 NORTE  24060330
# 121                 NORTE  24069728
# 122                 NORTE  24060356
# 123                 NORTE  24284319
# 124                 NORTE  24080039
# 125                 NORTE  24074071
# 126                 NORTE  24078697
# 127                 NORTE  24060372
# 128                 NORTE  24065927
# 129                 NORTE  24060704
# 130                 NORTE  24060348
# 131                 NORTE  24285340
# 132                 NORTE  24060674
# 133                 NORTE  24058963
# 134                 NORTE  24064980
# 135                 NORTE  24059188
# 136                 NORTE  24069663
# 137                 NORTE  24081850
# 138                 NORTE  24060380
# 139                 NORTE  24285331
# 140                 NORTE  24059196
# 141                 NORTE  24080047
# 142                 NORTE  24068985
# 143                 NORTE  24060399
# 144                 NORTE  24060402
#
#                                       ESTABELECIMENTO  \
# 0                          CMEI CLAUDETE COSTA MACIEL
# 1                CMEI HAYDEE MONTEIRO BEZERRA DE MELO
# 2                          CMEI KÁTIA FAGUNDES GARCIA
# 3                            CMEI MARIA CELONI CAMPOS
# 4                     CMEI MOEMA TINOCO DA CUNHA LIMA
# 5                  CMEI PROFA ANTÔNIA FERNANDA JALLES
# 6                        CMEI PROFA CARMEM MARIA REIS
# 7                         CMEI PROFA LIBÂNIA MEDEIROS
# 8       CMEI PROFA Mª DOS MARTIRIOS LISBOA DE MENEZES
# 9                       CMEI PROFA MARIA EUNICE DAVIM
# 10             CMEI PROFA MARIA LUIZA SANTOS DE SOUZA
# 11                  CMEI VILMA TEIXEIRA DOURADO DUTRA
# 12                                   CMEI AMOR DE MÃE
# 13                                 CMEI CLARA CAMARÃO
# 14              CMEI PROFA CLAUDIA OLIVEIRA DE FARIAS
# 15                CMEI PROFA DARILENE BRANDÃO MARTINS
# 16            CMEI GALDINA BARBOSÁ SILVEIRA GUIMARÃES
# 17                           CMEI JOSÉ ALVES SOBRINHO
# 18                  CMEI MARIA EULALIA GOMES DA SILVA
# 19                      CMEI NOSSA SENHORA DE LOURDES
# 20                        CMEI PADRE JOÃO PERESTRELLO
# 21                    CMEI PROFA VILMA MARIA DE FARIA
# 22                                CMEI BOM SÁMARITANO
# 23                      CMEI CARMEM FERNANDES PEDROZA
# 24                          CMEI CLEA BEZERRA DE MELO
# 25                                CMEI DRA ZILDA ARNS
# 26                                   CMEI FREI DAMIÃO
# 27                                    CMEI IRMA DULCE
# 28                             CMEI JESIEL FIGUEIREDO
# 29                              CMEI JESUS BOM PASTOR
# ..                                                ...
# 115                 ESC MUL NOSSA SRA DA APRESENTAÇÃO
# 116                     ESC MUL PROFA TEREZA SÁTSUQUI
# 117                  ESC MUL NOSSA SRA DOS NAVEGANTES
# 118                        ESC MUL PROF AMADEU ARAÚJO
# 119                      ESC MUL PROF EUDO JOSÉ ALVES
# 120                        ESC MUL PROF HERLY PARENTE
# 121               ESC MUL PROF JOSÉ DE ANDRADE FRAZÃO
# 122     ESC MUL PROF JOSÉ DO PRATOCÍNIO PEREIRA PINTO
# 123            ESC MUL PROF JOSÉ MELQUIADES DE MACEDO
# 124           ESC MUL PROF LAÉRCIO FERNANDES MONTEIRO
# 125              ESC MUL PROF REGINALDO FERREIRA NETO
# 126         ESC MUL PROF WALDSON JOSÉ BASTOS PINHEIRO
# 127                   ESC MUL PROFA ADELINA FERNANDES
# 128                   ESC MUL PROFA DALVA DE OLIVEIRA
# 129               ESC MUL PROFA FRANCISCA DE OLIVEIRA
# 130                    ESC MUL PROFA IAPISSÁRA AGUIAR
# 131               ESC MUL PROFA JOSEANE COUTINHO DIAS
# 132                     ESC MUL PROFA LOURDES GODEIRO
# 133                       ESC MUL PROFA MALVINA COSME
# 134           ESC MUL PROFA MARIA ALEXANDRINA SAMPAIO
# 135           ESC MUL PROFA MARIA DALVA GOMES BEZERRA
# 136  ESC MUL PROFA MARIA MADALENA XAVIER DE \nANDRADE
# 137               ESC MUL PROFA NOILDE PESSOA RAMALHO
# 138                    ESC MUL PROFA PALMIRA DE SOUZA
# 139                       ESC MUL PROFA TÂNIA ALMEIDA
# 140           ESC MUL PROFA TEREZINHA PAULINO DE LIMA
# 141            ESC MUL PROFA VERA LÚCIA SOARES BARROS
# 142        ESC MUL PROFA ZULEIDE FERNANDES DE M SILVA
# 143                            ESC MUL SANTA CATARINA
# 144                      ESC MUL VEREADOR JOSÉ SOTERO
#
#                                    ENDEREÇO            Nº  \
# 0                     RUA SERRA DOS CARAJAS          3160
# 1                          RUA JOSÉ SELEDON            70
# 2                RUA PROFESSORA ANA DJANIRA          1960
# 3                          RUA BAIA FORMOSÁ          1517
# 4                                 RUA JACUI           217
# 5                           RUA RIO SUASSUI          7701
# 6                  RUA JOÃO DE DEUS DE LIMA            SN
# 7                AV. SÃO MIGUEL DOS CARIBES          4334
# 8            RUA ENGENHEIRO JOAQUIM CARDOSO          2020
# 9                              RUA SOBRALIA           S/N
# 10                                  JANDAIA          8075
# 11                        RUA DOS AMARANTOS           156
# 12                       RUA FELICIANO DIAS           239
# 13                            RUA JAGUARARI          1122
# 14               RUA ESPLANADA SILVA JARDIM           169
# 15                     RUA AGOSTINHO LEITÃO           322
# 16                           RUA JOÃO XXIII          1565
# 17                  RUA JÚLIO GOMES MOREIRA           876
# 18              RUA NOSSA SENHORA APARECIDA            40
# 19                           RUA JOÃO XXIII          1215
# 20                           RUA JOÃO XXIII           729
# 21                    RUA MARCOS CAVALCANTE           585
# 22                 RUA PASTOR JOSINO GALVAO           102
# 23                            RUA JERUSÁLEM           115
# 24                    AV NSRA DO LIVRAMENTO            31
# 25   AV. INDUSTRIAL JOÃO FRANCISCO DA MOTTA            45
# 26                     RUA PEDRINHO BEZERRA          1185
# 27                            AV PERNAMBUCO            SN
# 28                     RUA HERMITA CANSÁCAO            SN
# 29              SOLANGE NUNES DO NASCIMENTO            56
# ..                                      ...           ...
# 115                            AV BOA SORTE           251
# 116                     AVENIDA MIRA MANGUE           205
# 117                         RUA DO CRUZEIRO           664
# 118                          RUA DOS CAROAS           S/N
# 119                           VITÓRIA RÉGIA           115
# 120                              RUA CAPELA            SN
# 121                            AV BOA SORTE          1834
# 122                      AVENIDA MANGABEIRA          1905
# 123                       RUA DAS PEDRINHAS           237
# 124                            R NOEL COSTA          1232
# 125                      RUA NOVA ESPERANÇA            SN
# 126                       RUA SÃO FRANCISCO           361
# 127            RUA ANGRA DOS REIS -CONJUNTO            SN
# 128                       AVENIDA BOA SORTE           639
# 129                RUA LINDOLFO GOMES VIDAL           230
# 130                              RUA ILHÉUS            SN
# 131                    AVENIDA CIDADE PRAIA          1240
# 132              MOEMA TINOCO DA CUNHA LIMA          4265
# 133                           RUA PARANDUVA          2903
# 134                          RUA DO ANEQUIM            SN
# 135                             RUA BARUERI           270
# 136                     AVENIDA VOTUPORANGA            35
# 137                      RUA MANOEL CAETANO           379
# 138                       RUA VOLTA REDONDA            SN
# 139                                FRAGATAS            37
# 140                            RUA MATINHOS  SEM \nNUMERO
# 141                      AV MAR MEDITERÂNEO          1236
# 142  AV. BARRAGEM ARMANDO RIBEIRO GONCALVES            SN
# 143   RUA PROF MARIA ARLETE DE L NASCIMENTO            SN
# 144                         AVENIDA ARACAJU           142
#
#                        BAIRRO       CEP        FONE
# 0                     PITIMBU  59068200  32328403.0
# 1                 PONTA NEGRA  59090215  32328413.0
# 2                  CANDELÁRIA  59064480  87291989.0
# 3               LAGOA NOVA II  59063060  32329443.0
# 4                    NEÓPOLIS  59080270  32328376.0
# 5                     PITIMBU  59068320         NaN
# 6                 PONTA NEGRA  59090318  32324812.0
# 7                    NEÓPOLIS  59086500  88145388.0
# 8                     PITIMBU  59069010  88877803.0
# 9                    NEÓPOLIS  59088680  87063068.0
# 10                    PITIMBU  59067290  32328404.0
# 11                 LAGOA NOVA  59078110  32326414.0
# 12              PRAIA DO MEIO  59010070  32328616.0
# 13             BARRO VERMELHO  59030500  32329433.0
# 14                    RIBEIRA  59012090  88018877.0
# 15                    ALECRIM  59040090  32329497.0
# 16                  MÃE LUÍZA  59014220  32328618.0
# 17             BARRO VERMELHO  59022110  32329480.0
# 18                CIDADE ALTA  59040085  32324792.0
# 19                  MÃE LUIZA  59014000  87687092.0
# 20                  MÃE LUIZA  59014000         NaN
# 21                      TIROL  59015300  32329482.0
# 22                    QUINTAS  59035050  32329500.0
# 23             FELIPE CAMARÃO  59074320  32056813.0
# 24                   GUARAPES  59074745  32324347.0
# 25             FELIPE CAMARÃO  59072200  36059161.0
# 26                 BOM PASTOR  59060480  32329493.0
# 27             FELIPE CAMARÃO  59072250  32329440.0
# 28        CIDADE DA ESPERANÇA  59070300  32329441.0
# 29           N. SRA DE NAZARÉ  59062170  32329447.0
# ..                        ...       ...         ...
# 115  N. SRA DA \nAPRESENTAÇÃO  59114250  32324845.0
# 116                  PLANALTO  59073230  36420052.0
# 117                   REDINHA  59122050  32324838.0
# 118                LAGOA AZUL  59138140  32324820.0
# 119  N. SRA DA \nAPRESENTAÇÃO  59114170  32324844.0
# 120                      IRMÃ  59104420  32324827.0
# 121  N. SRA DA \nAPRESENTAÇÃO  59114250  32328218.0
# 122                   POTENGI  59120420  32324823.0
# 123  N. SRA DA \nAPRESENTAÇÃO  59114410  32323875.0
# 124  N. SRA DA \nAPRESENTAÇÃO  59115575  32329238.0
# 125  N. SRA DA \nAPRESENTAÇÃO  59114510  32324870.0
# 126  N. SRA DA \nAPRESENTAÇÃO  59114155  32328198.0
# 127                   POTENGI  59127320  32324825.0
# 128  N. SRA DA \nAPRESENTAÇÃO  59114250  32324842.0
# 129                  PAJUCARA  59133560  32324832.0
# 130                   POTENGI  59108700  32324837.0
# 131                LAGOA AZUL  59129470  32324453.0
# 132                  PAJUCARA  59133090  32324830.0
# 133                   POTENGI  59110180  20207782.0
# 134                  PAJUCARA  59132450  32324833.0
# 135                LAGOA AZUL  59136350  32324831.0
# 136                   POTENGI  59133130  32324834.0
# 137                   REDINHA  59122060  32243676.0
# 138                   POTENGI  59110470  32324840.0
# 139                   PAJUARA  59132560  88385511.0
# 140  N. SRA DA \nAPRESENTAÇÃO  59114610  32324836.0
# 141                  PAJUCARA  59133010  32327791.0
# 142                  PAJUCARA  59133300  32324835.0
# 143                   POTENGI  59055000  32324841.0
# 144                      IRMÃ  59102120  32328249.0
#
# [145 rows x 8 columns]

# %%
#data3["GeoCod"] = data3["ESTABELECIMENTO"] + ", " + data3["ENDEREÇO"] + ", "+ data3["BAIRRO"]
data3['lat'], data3['long'] = [0, 0]

# %%
data3.head()
# Out:
#   Região Administrativa    CÓDIGO                       ESTABELECIMENTO  \
# 0                   SUL  24077720            CMEI CLAUDETE COSTA MACIEL
# 1                   SUL  24077739  CMEI HAYDEE MONTEIRO BEZERRA DE MELO
# 2                   SUL  24056936            CMEI KÁTIA FAGUNDES GARCIA
# 3                   SUL  24077267              CMEI MARIA CELONI CAMPOS
# 4                   SUL  24077500       CMEI MOEMA TINOCO DA CUNHA LIMA
#
#                      ENDEREÇO    Nº         BAIRRO       CEP        FONE  lat  \
# 0       RUA SERRA DOS CARAJAS  3160        PITIMBU  59068200  32328403.0    0
# 1            RUA JOSÉ SELEDON    70    PONTA NEGRA  59090215  32328413.0    0
# 2  RUA PROFESSORA ANA DJANIRA  1960     CANDELÁRIA  59064480  87291989.0    0
# 3            RUA BAIA FORMOSÁ  1517  LAGOA NOVA II  59063060  32329443.0    0
# 4                   RUA JACUI   217       NEÓPOLIS  59080270  32328376.0    0
#
#    long
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
# Retrieve the latitude and longitute related to each school
for i in tqdm(range(len(data3))):
    g = gc.google(data3.loc[i,'ESTABELECIMENTO'])
    if g.lat == None:
        str = data3.loc[i,'ENDEREÇO']+", "+ data3.loc[i,'BAIRRO']+" - RN"
        g = gc.google(str)
    data3.ix[i,'lat'] = g.lat
    data3.ix[i,'long'] = g.lng
print('Geocoding complete!')
# Out:
# 100%|██████████| 145/145 [02:46<00:00,  1.14s/it]
# Geocoding complete!

# %%
data3.head()
# Out:
#   Região Administrativa    CÓDIGO                       ESTABELECIMENTO  \
# 0                   SUL  24077720            CMEI CLAUDETE COSTA MACIEL
# 1                   SUL  24077739  CMEI HAYDEE MONTEIRO BEZERRA DE MELO
# 2                   SUL  24056936            CMEI KÁTIA FAGUNDES GARCIA
# 3                   SUL  24077267              CMEI MARIA CELONI CAMPOS
# 4                   SUL  24077500       CMEI MOEMA TINOCO DA CUNHA LIMA
#
#                      ENDEREÇO    Nº         BAIRRO       CEP        FONE  \
# 0       RUA SERRA DOS CARAJAS  3160        PITIMBU  59068200  32328403.0
# 1            RUA JOSÉ SELEDON    70    PONTA NEGRA  59090215  32328413.0
# 2  RUA PROFESSORA ANA DJANIRA  1960     CANDELÁRIA  59064480  87291989.0
# 3            RUA BAIA FORMOSÁ  1517  LAGOA NOVA II  59063060  32329443.0
# 4                   RUA JACUI   217       NEÓPOLIS  59080270  32328376.0
#
#         lat       long
# 0 -5.861867 -35.237338
# 1 -5.889422 -35.171142
# 2 -5.843191 -35.218472
# 3 -5.820928 -35.224054
# 4 -5.858978 -35.206216

# %%
# Export the dataSet to csv
data3.to_csv('GeoCode_Escolas.csv', encoding="utf-8")

# %% [markdown]
# ### Gelocation - health units

# %%
# Retrieve the health units geolocation
data1['lat'], data1['long'] = [0, 0]

for i in tqdm(range(len(data1))):
    g = gc.google(data1.loc[i,'Unidade'])
    data1.ix[i,'lat'] = g.lat
    data1.ix[i,'long'] = g.lng
print('Geocoding complete!')
# Out:
# 100%|██████████| 1023/1023 [09:09<00:00,  1.94it/s]
# Geocoding complete!

# %%
data1.head()
# Out:
#   Distrito Sanitário           Unidade         Serviços Oferecidos  \
# 0              Leste  CAPS AD II LESTE      Consulta Clinico Geral
# 1              Leste  CAPS AD II LESTE         Consulta Enfermagem
# 2              Leste  CAPS AD II LESTE           Consulta Nutrição
# 3              Leste  CAPS AD II LESTE      Consulta de Psicologia
# 4              Leste  CAPS AD II LESTE  Consulta Assistente Social
#
#                   Tipo de Unidade       lat       long
# 0  CENTRO DE ATENÇÃO PSICOSSOCIAL -5.786882 -35.200245
# 1  CENTRO DE ATENÇÃO PSICOSSOCIAL -5.786882 -35.200245
# 2  CENTRO DE ATENÇÃO PSICOSSOCIAL -5.786882 -35.200245
# 3  CENTRO DE ATENÇÃO PSICOSSOCIAL -5.786882 -35.200245
# 4  CENTRO DE ATENÇÃO PSICOSSOCIAL -5.786882 -35.200245

# %%
# Export the health unit dataSet to .csv
data1.to_csv('GeoCode_Saude.csv', encoding="utf-8")

# %%
# Read the generate csv
geodata1 = pd.read_csv('GeoCode_Escolas.csv', encoding="utf-8", index_col=0)
geodata2= pd.read_csv('GeoCode_Saude.csv', encoding="utf-8", index_col=0)

# %%
# Retrieve the data related to geolocalization
geodata = geodata1.filter(['ESTABELECIMENTO','lat','long'], axis=1)
geodata = geodata.rename(columns = {'ESTABELECIMENTO':'Unidade'})
geodata = geodata.append( geodata2.filter(['Unidade','lat','long'], axis=1))

# Reset the index
geodata = geodata.reset_index()

# Remove the the previous index
geodata.drop(geodata.columns[0], axis=1, inplace=True)
#geodata.head()

# %%
# Set map center and zoom level
mapc = [-5.788, -35.202]
zoom = 11

# Create map object
map_osm = folium.Map(location=mapc, zoom_start=zoom)

# Plot each of the locations that we geocoded
for j in tqdm(range(len(geodata))):
    folium.Marker([geodata.ix[j,'lat'], geodata.ix[j,'long']],
                  #popup=(geodata.ix[j,'Unidade'])
                 ).add_to(map_osm)
# Show the map
map_osm
# Out:
# 100%|██████████| 1168/1168 [00:17<00:00, 67.10it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Retrieve the professionals by region
dLeste = "http://ckan.imd.ufrn.br/dataset/c434f105-bc9e-4415-aeb7-6ec54d6d0351/resource/c6480b62-4ade-4b80-a918-1c22dcef7c68/download/profissionais-das-unidades-do-distrito-leste.csv"
dNortI = "http://ckan.imd.ufrn.br/dataset/c434f105-bc9e-4415-aeb7-6ec54d6d0351/resource/f90b1a83-d17e-4ada-88d8-0dc8003634a9/download/profissionais-das-unidades-do-distrito-norte-i.csv"
dNorteII = "http://ckan.imd.ufrn.br/dataset/c434f105-bc9e-4415-aeb7-6ec54d6d0351/resource/f0ffb77f-9f4d-4f0f-82d3-089d2126789f/download/profissionais-das-unidades-do-distrito-norte-ii.csv"
dOeste = "http://ckan.imd.ufrn.br/dataset/c434f105-bc9e-4415-aeb7-6ec54d6d0351/resource/486f84b9-00ac-456b-bdd4-fad57af19cf9/download/profissionais-das-unidades-do-distrito-oeste.csv"
dSul = "http://ckan.imd.ufrn.br/dataset/c434f105-bc9e-4415-aeb7-6ec54d6d0351/resource/73902e96-f86f-4ab9-9887-c38b2c1f3d60/download/profissionais-das-unidades-do-distrito-sul.csv"

# Split the data using ';'
dataH = pd.read_csv(dLeste, sep=";")
dataH2 = pd.read_csv(dNortI, sep=";")
dataH3 = pd.read_csv(dNorteII, sep=";")
dataH4 = pd.read_csv(dOeste, sep=";")
dataH5 = pd.read_csv(dSul, sep=";")

# Append all dataSet in only one variable
dataH = dataH.append(dataH2).append(dataH3).append(dataH4).append(dataH5)

# Print the dataSet head
dataH.head()
# Out:
#      UNIDADE             NOME DO PROFISSIONAL ESPECIALIDADE  \
# 0  APARECIDA        PATRICIA ARBOES PETRONILO        MÉDICO
# 1  APARECIDA      ANA LILIAN PROTASIO DE LIMA        MÉDICO
# 2  APARECIDA  NEUMA MARINHO DE QUEIROZ SANTOS        MÉDICO
# 3  APARECIDA      MARIA CRISTINA VARELA BARCA    ENFERMEIRO
# 4  APARECIDA     MAGNA MARIA PEREIRA DA SILVA    ENFERMEIRO
#
#                            HORÁRIO
# 0  07:30 ÁS 11:30 / 14:00 ÁS 17:00
# 1  07:30 ÁS 11:30 / 14:00 ÁS 17:00
# 2  07:30 ÁS 11:30 / 14:00 ÁS 17:00
# 3  07:30 ÁS 11:30 / 14:00 ÁS 17:00
# 4  07:30 ÁS 11:30 / 14:00 ÁS 17:00

# %%
# Do some fix in final data
dataFinal = dataH.copy()
dataFinal.drop(dataFinal.columns[-3:], axis=1, inplace=True)
dataFinal["Count"] = 0

# Print the dataSet head
dataFinal.head()
# Out:
#      UNIDADE  Count
# 0  APARECIDA      0
# 1  APARECIDA      0
# 2  APARECIDA      0
# 3  APARECIDA      0
# 4  APARECIDA      0

# %%
# Cound the number of units by neighborhood
dataFinal = pd.DataFrame(dataFinal.groupby(["UNIDADE"])['Count'].count()).reset_index()

# Print the dataSet head
dataFinal.head()
# Out:
#             UNIDADE  Count
# 0         APARECIDA     31
# 1   BAIRRO NORDESTE     39
# 2        BOM PASTOR     37
# 3  BRASÍLIA TEIMOSA     17
# 4       CIDADE NOVA     40

# %%
# Retrieve the latitude and longitude
dataFinal['lat'], dataFinal['long'] = [0, 0]

for i in tqdm(range(len(dataFinal))):
    g = gc.google("Unidade Saude"+dataFinal.loc[i,'UNIDADE']+" RN")
    dataFinal.ix[i,'lat'] = g.lat
    dataFinal.ix[i,'long'] = g.lng
print('Geocoding complete!')
dataFinal
# Out:
# 100%|██████████| 39/39 [00:40<00:00,  1.05s/it]
# Geocoding complete!
#                    UNIDADE  Count       lat       long
# 0                APARECIDA     31 -5.792801 -35.187280
# 1          BAIRRO NORDESTE     39 -5.796688 -35.242233
# 2               BOM PASTOR     37 -5.809690 -35.235417
# 3         BRASÍLIA TEIMOSA     17 -5.776584 -35.197312
# 4              CIDADE NOVA     40 -5.858202 -35.241673
# 5             CIDADE PRAIA     22 -5.739238 -35.267214
# 6         FELIPE CAMARÃO I     41 -5.829223 -35.249099
# 7        FELIPE CAMARÃO II     45 -5.815283 -35.249299
# 8       FELIPE CAMARÃO III     61 -5.824543 -35.264234
# 9                  GRAMORÉ     34 -5.728282 -35.253950
# 10                 GUARITA     31 -5.795655 -35.223512
# 11                   IGAPÓ     33 -5.761366 -35.275648
# 12             JOSÉ SARNEY     18 -5.737301 -35.257059
# 13            MONTE LÍBANO     28 -5.807896 -35.241781
# 14                  NAZARÉ     29 -5.815624 -35.233501
# 15             NORDELÂNDIA     21 -5.730178 -35.269459
# 16             NOVA CIDADE     23 -5.835899 -35.230311
# 17              NOVA NATAL     62 -5.825555 -35.203643
# 18                PAJUÇARA     29 -5.729621 -35.247193
# 19                 PANATIS     35 -5.760700 -35.261226
# 20        PARQUE DAS DUNAS     26 -5.731602 -35.233171
# 21    PARQUE DOS COQUEIROS     40 -5.761366 -35.275648
# 22         PASSO DA PÁTRIA     23 -5.788220 -35.214496
# 23                PLANALTO     36 -5.655461 -35.422350
# 24  PLANÍCE DAS MANGUEIRAS     30 -5.748723 -35.270437
# 25                 POMPÉIA     23 -5.742460 -35.243711
# 26             PONTA NEGRA     16 -5.884378 -35.172599
# 27                 POTENGI     41 -5.760700 -35.261226
# 28                 QUINTAS      9 -5.796737 -35.235338
# 29              QUINTAS II     31       NaN        NaN
# 30                 REDINHA     18 -5.751523 -35.234085
# 31                   ROCAS     40 -5.773486 -35.198344
# 32          SANTA CATARINA     19 -5.756779 -35.260573
# 33                SANTARÉM     41 -5.739423 -35.252276
# 34              SOLEDADE I     19 -5.749834 -35.254546
# 35             SOLEDADE II     42 -5.749834 -35.254546
# 36            VALE DOURADO     33 -5.762155 -35.271043
# 37             VISTA VERDE     41 -5.736549 -35.240794
# 38                  ÁFRICA     23 -5.745151 -35.214048

# %% [markdown]
# ## HeatMap

# %%
# Set map center and zoom level
mapc = [-5.788, -35.202]
zoom = 11

# Initialize the coordinates array
coordinates = []

# Add the coordinates to the coordinate
for i in range(len(dataFinal)):
    # eliminate items with'nan' element
    if all(~np.isnan([dataFinal.ix[i,'lat'], dataFinal.ix[i,'long'], dataFinal.ix[i,'Count']])):
        coordinates.append([dataFinal.ix[i,'lat'], dataFinal.ix[i,'long'], dataFinal.ix[i,'Count']])

# Create map object
htMap = folium.Map(location=mapc, zoom_start=zoom)

# Append the coordinates to the heatMap
HeatMap(coordinates).add_to(htMap)

# Print the heatMap
htMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
